# %% [markdown]
# # Lab | Pandas

# %% [markdown]
# Objective: practice how to use the pandas library in Python for data analysis and manipulation.

# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# The data includes information such as customer ID, state, gender, education, income, and other variables that can be used to perform various analyses.
#
# Throughout the lab, we will be using the pandas library in Python to manipulate and analyze the data. Pandas is a powerful library that provides various data manipulation and analysis tools, including the ability to load and manipulate data from a variety of sources, including CSV files.

# %% [markdown]
# ### Data Description
#
# - Customer - Customer ID
#
# - ST - State where customers live
#
# - Gender - Gender of the customer
#
# - Education - Background education of customers
#
# - Customer Lifetime Value - Customer lifetime value(CLV) is the total revenue the client will derive from their entire relationship with a customer. In other words, is the predicted or calculated value of a customer over their entire duration as a policyholder with the insurance company. It is an estimation of the net profit that the insurance company expects to generate from a customer throughout their relationship with the company. Customer Lifetime Value takes into account factors such as the duration of the customer's policy, premium payments, claim history, renewal likelihood, and potential additional services or products the customer may purchase. It helps insurers assess the long-term profitability and value associated with retaining a particular customer.
#
# - Income - Customers income
#
# - Monthly Premium Auto - Amount of money the customer pays on a monthly basis as a premium for their auto insurance coverage. It represents the recurring cost that the insured person must pay to maintain their insurance policy and receive coverage for potential damages, accidents, or other covered events related to their vehicle.
#
# - Number of Open Complaints - Number of complaints the customer opened
#
# - Policy Type - There are three type of policies in car insurance (Corporate Auto, Personal Auto, and Special Auto)
#
# - Vehicle Class - Type of vehicle classes that customers have Two-Door Car, Four-Door Car SUV, Luxury SUV, Sports Car, and Luxury Car
#
# - Total Claim Amount - the sum of all claims made by the customer. It represents the total monetary value of all approved claims for incidents such as accidents, theft, vandalism, or other covered events.

# %% [markdown]
# External Resources: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %% [markdown]
# ## Challenge 1: Understanding the data
#
# In this challenge, you will use pandas to explore a given dataset. Your task is to gain a deep understanding of the data by analyzing its characteristics, dimensions, and statistical properties.

# %% [markdown]
# - Identify the dimensions of the dataset by determining the number of rows and columns it contains.
# - Determine the data types of each column and evaluate whether they are appropriate for the nature of the variable. You should also provide suggestions for fixing any incorrect data types.
# - Identify the number of unique values for each column and determine which columns appear to be categorical. You should also describe the unique values of each categorical column and the range of values for numerical columns, and give your insights.
# - Compute summary statistics such as mean, median, mode, standard deviation, and quartiles to understand the central tendency and distribution of the data for numerical columns. You should also provide your conclusions based on these summary statistics.
# - Compute summary statistics for categorical columns and providing your conclusions based on these statistics.

# %%
import pandas as pd

# %%
file1 = pd.read_csv('file1.csv')
file1.shape
display(file1)
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                1000.0
# 1                 697953.59%       0                  94.0
# 2                1288743.17%   48767                 108.0
# 3                 764586.18%       0                 106.0
# ...

# %% [markdown]
# I quitted all the NaN that are just empty spaces at the end that had downloaded with the CSV file

# %%
file1.isna().sum()
# Out:
# Customer                       0
# ST                             0
# GENDER                       117
# Education                      0
# Customer Lifetime Value        3
# Income                         0
# Monthly Premium Auto           0
# Number of Open Complaints      0
# Policy Type                    0
# Vehicle Class                  0
# Total Claim Amount             0
# dtype: int64

# %%
file1 = file1[file1['Customer Lifetime Value'].isna()==False]

# %%
round(file1.isna().sum()/len(file1),4)*100  # shows the percentage of null values in a column
nulls_df = pd.DataFrame(round(file1.isna().sum()/len(file1),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                   header_name  percent_nulls
# 0                    Customer           0.00
# 1                          ST           0.00
# 2                      GENDER          10.86
# 3                   Education           0.00
# 4     Customer Lifetime Value           0.00
# 5                      Income           0.00
# 6        Monthly Premium Auto           0.00
# 7   Number of Open Complaints           0.00
# 8                 Policy Type           0.00
# 9               Vehicle Class           0.00
# 10         Total Claim Amount           0.00

# %%
#Clean file1 VERSION 1
file1.to_csv('file1_clean.csv', index=False)

# %%
file1_clean = pd.read_csv('file1_clean.csv')

# %%
data_types = file1_clean.dtypes

print(data_types)
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                         int64
# Monthly Premium Auto         float64
# Number of Open Complaints    float64
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %% [markdown]
# Data type that should be changed: Customer lifetime value -> float/interger and Number of Open Complaints -->Interger/float

# %%
#Convert Life Time Value into a float
file1_clean['Customer Lifetime Value'] = file1_clean['Customer Lifetime Value'].str.replace('%', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[137], line 2
#       1 #Convert Life Time Value into a float
# ----> 2 file1_clean['Customer Lifetime Value'] = file1_clean['Customer Lifetime Value'].str.replace('%', '').astype(float)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
# ...

# %%
#Convert Number of open complaints into a float (ASSUMPTION! 1/2/0 = 3 complaints open, and so for)
def sum_and_convert_to_float(date_string):
    parts = date_string.split('/')
    sum_values = sum(map(int, parts))
    return float(sum_values)
file1_clean['Number of Open Complaints'] = file1_clean['Number of Open Complaints'].apply(sum_and_convert_to_float)

# %%
#Get the unique values to see if gender or other have a typo as always and fix it
unique_values_per_column = {}
for column in file1_clean.columns:
    unique_values_per_column[column] = file1_clean[column].unique()

for column, unique_values in unique_values_per_column.items():
    print(f"Unique values for '{column}': {unique_values}")
# Out:
# Unique values for 'Customer': ['QZ44356' 'AI49188' 'WW63253' ... 'GS98873' 'CW49887' 'MY31220']
# Unique values for 'ST': ['Arizona' 'Nevada' 'California' 'Washington' 'Oregon' 'Cali' 'AZ' 'WA']
# Unique values for 'GENDER': ['F' 'M' 0]
# Unique values for 'Education': ['Bachelor' 'High School or Below' 'College' 'Master' 'Bachelors' 'Doctor']
# Unique values for 'Customer Lifetime Value': [ 697953.59 1288743.17  764586.18 ... 2031499.76  323912.47  899704.02]
# Unique values for 'Income': [    0 48767 36357 62902 55350 14072 28812 77026 99845 83689 24599 25049
#  28855 51148 66140 57749 61040 17870 97541 29723 86584 75690 23158 65999
#  37260 68987 42305 65706 53243 50071 60021 43244 46896 10105 23218 24804
#  33190 36014 67163 16701 46623 64749 16969 11621 17622 11489 66525 33663
#  22547 61486 29879 93011 65186 26840 75644 38984 71811 20961 61321 51066
#  34378 43072 25222 77552 23091 48269 32720 20396 21513 80744 52822 69738
# ...

# %%
#Substitute gender into only common values
value_mapping = {
    'Femal': 'F',
    'Female': 'F',
    "female": "F",
    'M': 'M',
    'Male': 'M',  
}

file1_clean['GENDER'] = file1_clean['GENDER'].replace(value_mapping)

# %%
#Substitute ST to same values ('Arizona' 'Nevada' 'California' 'Washington' 'Oregon' 'Cali' 'AZ' 'WA')
value_mapping = {
    'Arizona': 'Arizona',
    'AZ': 'Arizona',
    "Nevada": "Nevada",
    'Cali': 'California',
    'California': 'California',
    "Washinton": "Washington",
    "WA":"Washington",
    "Oregon":"Oregon"  
}

file1_clean['ST'] = file1_clean['ST'].replace(value_mapping)

# %%
file1_clean
# Out:
#      Customer          ST GENDER             Education  \
# 0     QZ44356     Arizona      F              Bachelor
# 1     AI49188      Nevada      F              Bachelor
# 2     WW63253  California      M              Bachelor
# 3     GA49547  Washington      M  High School or Below
# 4     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1063  TM65736      Oregon      M                Master
# 1064  VJ51327  California      F  High School or Below
# 1065  GS98873     Arizona      F              Bachelor
# 1066  CW49887  California      F                Master
# 1067  MY31220  California      F               College
#
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                   697953.59       0                  94.0
# 1                  1288743.17   48767                 108.0
# 2                   764586.18       0                 106.0
# ...

# %%
#CLEAN CSV. FINAL VERSION AKA TERMINATOR
file1_clean.to_csv('file1_terminator.csv', index=False)

# %%
file1_terminator = pd.read_csv('file1_terminator.csv')

# %%
unique_value_per_colum = file1_terminator.nunique()

print(unique_value_per_colum)
# Out:
# Customer                     1068
# ST                              5
# GENDER                          3
# Education                       6
# Customer Lifetime Value      1027
# Income                        772
# Monthly Premium Auto          131
# Number of Open Complaints       6
# Policy Type                     3
# Vehicle Class                   6
# Total Claim Amount            758
# dtype: int64

# %%
categorical_columns = file1_terminator.columns[file1_terminator.dtypes == 'object']

for col in categorical_columns:
    unique_values = file1_terminator[col].unique()
    print(f"Unique values for '{col}': {unique_values}")

numerical_columns = file1_terminator.columns[file1_terminator.dtypes != 'object']
numerical_description = file1_terminator[numerical_columns].describe()
print(numerical_description)
# Out:
# Unique values for 'Customer': ['QZ44356' 'AI49188' 'WW63253' ... 'GS98873' 'CW49887' 'MY31220']
# Unique values for 'ST': ['Arizona' 'Nevada' 'California' 'Washington' 'Oregon']
# Unique values for 'GENDER': ['F' 'M' '0']
# Unique values for 'Education': ['Bachelor' 'High School or Below' 'College' 'Master' 'Bachelors' 'Doctor']
# Unique values for 'Policy Type': ['Personal Auto' 'Corporate Auto' 'Special Auto']
# Unique values for 'Vehicle Class': ['Four-Door Car' 'Two-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car']
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count             1.068000e+03   1068.000000           1068.000000
# mean              7.936903e+05  39315.411985            192.691948
# std               6.434784e+05  30484.373979           1603.241719
# min               2.004351e+05      0.000000             61.000000
# 25%               4.034080e+05  14072.000000             68.000000
# ...

# %%
categorical_summary = file1_terminator.describe (include = "object")
print(categorical_summary)
# Out:
#        Customer          ST GENDER Education    Policy Type  Vehicle Class
# count      1068        1068   1068      1068           1068           1068
# unique     1068           5      3         6              3              6
# top     QZ44356  California      F  Bachelor  Personal Auto  Four-Door Car
# freq          1         331    501       324            777            573

# %% [markdown]
# Conclsions of the summary statistics:
#     Customer Life Time Value: A costumer values on average 700k$ with a min of 200k$ and a max of 5M$. We can get from the data that there is a  disperssion Std > Mean.
#     Relevant factors: Monthly premium auto has a huge disperssion. Number of complaints at it Amount, are not disperesed as we can expect.
#     Disperssion std > mean
#     Non disperssion stf > mrsn
#
# Colclusions of the categorical summary:
#     We don't have to same costumers, we only have 8 states, the majority are females (but only 501/1068, therefore it's moreless even), same happens with bachelor, mainly people have the Policy type and a bit more of 50% of the inssured have a Four-Door Car

# %% [markdown]
# ## Challenge 2: analyzing the data

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# The marketing team wants to know the top 5 less common customer locations. Create a pandas Series object that contains the customer locations and their frequencies, and then retrieve the top 5 less common locations in ascending order.

# %%
customer_locations = file1_terminator['ST']

customer_locations_freq = customer_locations.value_counts()

top_5_less_common_locations = customer_locations_freq.nsmallest(5)

print (top_5_less_common_locations)
# Out:
# Nevada         98
# Washington    108
# Arizona       211
# Oregon        320
# California    331
# Name: ST, dtype: int64

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Your goal is to identify customers with a high policy claim amount.
#
# Instructions:
#
# - Review again the statistics for total claim amount to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount data.

# %% [markdown]
# *Note: When analyzing data, we often want to focus on certain groups of values to gain insights. Percentiles are a useful tool to help us define these groups. A percentile is a measure that tells us what percentage of values in a dataset are below a certain value. For example, the 75th percentile represents the value below which 75% of the data falls. Similarly, the 25th percentile represents the value below which 25% of the data falls. When we talk about the top 25%, we are referring to the values that fall above the 75th percentile, which represent the top quarter of the data. On the other hand, when we talk about the bottom 25%, we are referring to the values that fall below the 25th percentile, which represent the bottom quarter of the data. By focusing on these groups, we can identify patterns and trends that may be useful for making decisions and taking action.*
#
# *Hint: look for a method that gives you the percentile or quantile 0.75 and 0.25 for a Pandas Series.*

# %% [markdown]
# *Hint 2: check `Boolean selection according to the values of a single column` in https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9*

# %%
policy_claim_amounts = file1_terminator['Total Claim Amount']

percentile_75 = policy_claim_amounts.quantile(0.75)

high_claim_customers_df = file1_terminator[file1_terminator['Total Claim Amount'] > percentile_75]

summary_statistics = high_claim_customers_df.describe()


print(summary_statistics)
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count             2.640000e+02    264.000000            264.000000
# mean              9.086868e+05  23677.344697            165.193182
# std               6.387678e+05  27013.483721            623.930992
# min               2.287597e+05      0.000000             63.000000
# 25%               4.723958e+05      0.000000             99.000000
# 50%               7.781768e+05  18807.000000            114.000000
# 75%               1.054430e+06  42423.750000            133.250000
# max               3.844586e+06  99316.000000          10202.000000
#
#        Number of Open Complaints  Total Claim Amount
# count                 264.000000          264.000000
# mean                    1.416667          782.228263
# std                     0.943593          292.751640
# min                     1.000000          537.600000
# 25%                     1.000000          606.521741
# ...

# %% [markdown]
# ### Exercise 3
#
# The sales team wants to know the total number of policies sold for each type of policy. Create a pandas Series object that contains the policy types and their total number of policies sold, and then retrieve the policy type with the highest number of policies sold.

# %% [markdown]
# *Hint:*
# - *Using value_counts() method simplifies this analysis.*
# - *Futhermore, there is a method that returns the index of the maximum value in a column or row.*

# %%
# Your code here

# %% [markdown]
# ### Exercise 4
#
# The sales team wants to know if customers with Personal Auto have a income than those with Corporate Auto. How does the average income compare between the two policy types?

# %% [markdown]
# - Use *loc* to create two dataframes: one containing only Personal Auto policies and one containing only Corporate Auto policies.
# - Calculate the average income for each policy.
# - Print the results.

# %%
# Your code here
